# %% [markdown]
# <a href="https://colab.research.google.com/github/Sheetal-jain-2006/research-project/blob/main/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Sample data
data = {
    "Name": ["A", "B", "C", "D"],
    "Marks": [80, 75, 90, 85]
}

df = pd.DataFrame(data)

print(df)
print("Average Marks:", df["Marks"].mean())
# Out:
#   Name  Marks
# 0    A     80
# 1    B     75
# 2    C     90
# 3    D     85
# Average Marks: 82.5
